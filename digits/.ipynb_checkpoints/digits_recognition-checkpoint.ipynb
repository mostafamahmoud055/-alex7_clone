# %%
from skimage.io import imread
from skimage.transform import resize
import os
import glob
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

# %%
folders=glob.glob("./data/*")

# %%
X=[]
y=[]
for folder in folders:
    files=glob.glob(folder+"/*")
    for file in files:
        im=imread(file)
        im=resize(im,(28,28))
        im=im.flatten()
        y.append(int(folder.split("\\")[-1]))
        X.append(im)

# %%
X_train,X_test,y_train,y_tes=train_test_split(np.array(X),np.array(y),random_state=42)

# %%
cl=DecisionTreeClassifier()

# %%
cl.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
preds=cl.predict(X_test)

# %%
print(classification_report(y_tes,preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91       278
#            1       0.86      0.93      0.89       271
#            2       0.90      0.91      0.90       265
#            3       0.88      0.84      0.86       280
#            4       0.87      0.86      0.86       264
#            5       0.84      0.83      0.83       274
#            6       0.86      0.81      0.83       256
#            7       0.92      0.88      0.90       266
#            8       0.85      0.85      0.85       248
#            9       0.84      0.89      0.87       250
#
#     accuracy                           0.87      2652
#    macro avg       0.87      0.87      0.87      2652
# weighted avg       0.87      0.87      0.87      2652

# %%
im=imread("C:\\Users\\Mohammed\\Alex7\\zero.jpg")

# %%
im=resize(np.invert(im[:,:,0]),(28,28))

# %%
plt.imshow(im,cmap='gray')

# %%
im=im.flatten()

# %%
im.shape
# Out:
# (784,)

# %%
cl.predict(im.reshape(1,-1))
# Out:
# array([0])
