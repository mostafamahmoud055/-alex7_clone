# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import seaborn as sb
from sklearn.datasets import fetch_california_housing

# %%
x = np.arange(0, 30)
y = [3, 4, 5, 7, 10, 8, 9, 10, 10, 23, 27, 44, 50, 63, 67, 60, 
     62, 70, 75, 88, 81, 87, 95, 100, 108, 135, 151, 160, 169, 179]
plt.figure(figsize=(4,4))
plt.scatter(x, y)
plt.show()

# %%
poly = PolynomialFeatures(degree=2, include_bias=False)

# %%
poly_features = poly.fit_transform(x.reshape(-1, 1))

# %%
poly_features[2]
# Out:
# array([2., 4.])

# %%
poly_features = poly.fit_transform(x.reshape(-1, 1))

# %%
poly_reg_model = LinearRegression()
poly_reg_model.fit(poly_features, y)
# Out:
# LinearRegression()

# %%
y_predicted = poly_reg_model.predict(poly_features)

# %%
plt.figure(figsize=(10, 6))
plt.title("Y", size=16)
plt.scatter(x, y)
plt.plot(x, y_predicted, c="red")
plt.show()

# %%
np.random.seed(1)
x_1 = np.absolute(np.random.randn(100, 1) * 10)
x_2 = np.absolute(np.random.randn(100, 1) * 30)
y = 2*x_1**2 + 3*x_1 + 2 + np.random.randn(100, 1)*20

# %%
X=np.hstack((x_1,x_2))

# %%
np.random.randn()
# Out:
# 2.0657833202188343

# %%
x_1.shape
# Out:
# (100, 1)

# %%
poly2=PolynomialFeatures(degree=2, include_bias=False)
X=np.hstack((x_1,x_2))

# %%
poly_features2=poly2.fit_transform(X)

# %%
poly_reg_model = LinearRegression()
poly_reg_model.fit(poly_features2, y)
# Out:
# LinearRegression()

# %%
y_hat=poly_reg_model.predict(poly_features2)

# %%
# plt.figure(figsize=(10, 6))
# plt.title("Y", size=16)
# plt.scatter(x_1, y)
plt.plot(x_1, y, c="red")
plt.show()

# %%
poly_reg_model.coef_
# Out:
# array([[ 4.5303673 , -0.90520045,  1.86944627,  0.00889955,  0.01264488]])

# %%
sb.lineplot(x=x_1.reshape(-1,),y=y.reshape(-1,))
# Out:
# <Axes: >

# %%
sb.lineplot(x=x_2.reshape(-1,),y=y.reshape(-1,))
# Out:
# <Axes: >

# %%
X,y=fetch_california_housing(return_X_y=True)
df=pd.DataFrame(X)

# %%
X_train,X_test,y_train,y_test=train_test_split(df,y)

# %% [markdown]
# # Feature Engineering

# %%
poly3=PolynomialFeatures(degree=2,include_bias=False)
poly_features3=poly3.fit_transform(X_train)

# %% [markdown]
# # Modeling

# %%
poly_reg_model3 = LinearRegression()
poly_reg_model3.fit(poly_features3, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Testing

# %%
poly3_test=poly3.transform(X_test)

# %%
y3_hat=poly_reg_model3.predict(poly3_test)

# %%
y3_hat
# Out:
# array([1.63128083, 7.45411404, 1.62679623, ..., 2.85918161, 1.46384509,
#        2.68835195])

# %%
poly3.fit_transform(X_train)
# Out:
# array([[ 3.71620000e+00,  1.60000000e+01,  4.91651865e+00, ...,
#          1.13838760e+03, -3.97963300e+03,  1.39122025e+04],
#        [ 4.01090000e+00,  2.30000000e+01,  5.44063325e+00, ...,
#          1.10290410e+03, -3.89686140e+03,  1.37686756e+04],
#        [ 6.57430000e+00,  1.00000000e+01,  7.07286432e+00, ...,
#          1.13703840e+03, -3.97120440e+03,  1.38697729e+04],
#        ...,
#        [ 4.42500000e+00,  3.50000000e+01,  4.72395833e+00, ...,
#          1.41902890e+03, -4.61231480e+03,  1.49915536e+04],
#        [ 1.91250000e+00,  3.60000000e+01,  3.33272059e+00, ...,
#          1.16553960e+03, -4.03671360e+03,  1.39806976e+04],
#        [ 1.80680000e+00,  3.40000000e+01,  3.90663391e+00, ...,
#          1.33517160e+03, -4.36251060e+03,  1.42539721e+04]])

# %%
poly3.transform(X_train)
# Out:
# array([[ 3.71620000e+00,  1.60000000e+01,  4.91651865e+00, ...,
#          1.13838760e+03, -3.97963300e+03,  1.39122025e+04],
#        [ 4.01090000e+00,  2.30000000e+01,  5.44063325e+00, ...,
#          1.10290410e+03, -3.89686140e+03,  1.37686756e+04],
#        [ 6.57430000e+00,  1.00000000e+01,  7.07286432e+00, ...,
#          1.13703840e+03, -3.97120440e+03,  1.38697729e+04],
#        ...,
#        [ 4.42500000e+00,  3.50000000e+01,  4.72395833e+00, ...,
#          1.41902890e+03, -4.61231480e+03,  1.49915536e+04],
#        [ 1.91250000e+00,  3.60000000e+01,  3.33272059e+00, ...,
#          1.16553960e+03, -4.03671360e+03,  1.39806976e+04],
#        [ 1.80680000e+00,  3.40000000e+01,  3.90663391e+00, ...,
#          1.33517160e+03, -4.36251060e+03,  1.42539721e+04]])

# %%
U=np.hstack((x_1,x_2))

# %%
poly2.fit_transform(U)[0]
# Out:
# array([ 16.24345364,  13.41385694, 263.84978605, 217.88736335,
#        179.9315581 ])

# %%
p=PolynomialFeatures(degree=2,include_bias=False)

# %%
poly_reg_model3.score(poly3_test,y_test)
# Out:
# 0.5079504352323638
