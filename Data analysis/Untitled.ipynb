# %%
import numpy as np
import statsmodels.api as sm
import pandas as pd

# %%
df=pd.read_csv("house_prices.csv")

# %%
df.head()
# Out:
#    house_id neighborhood  area  bedrooms  bathrooms      style    price
# 0      1112            B  1188         3          2      ranch   598291
# 1       491            B  3512         5          3  victorian  1744259
# 2      5952            B  1134         3          2      ranch   571669
# 3      3525            A  1940         4          2      ranch   493675
# 4      5108            B  2208         6          4  victorian  1101539

# %%
df['intercept']=1

# %%
lm=sm.OLS(df['price'],df[['area','bedrooms','bathrooms','bedrooms']])

res=lm.fit()

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared (uncentered):                   0.895
# Model:                            OLS   Adj. R-squared (uncentered):              0.895
# Method:                 Least Squares   F-statistic:                          1.717e+04
# Date:                Mon, 05 Aug 2024   Prob (F-statistic):                        0.00
# Time:                        14:51:37   Log-Likelihood:                         -84517.
# No. Observations:                6028   AIC:                                  1.690e+05
# Df Residuals:                    6025   BIC:                                  1.691e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
